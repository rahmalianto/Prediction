# %%
import csv
import numpy as np
import pandas as pd
from chefboost import Chefboost as chef

# %%
data = pd.read_csv('bank-additional/bank-additional.csv', sep=';')
# data.head()
training_set = data.loc[0:999]
test_set = data.loc[999:4119]
training_set.head()
# Out:
#    age          job  marital          education default  housing     loan  \
# 0   30  blue-collar  married           basic.9y      no      yes       no
# 1   39     services   single        high.school      no       no       no
# 2   25     services  married        high.school      no      yes       no
# 3   38     services  married           basic.9y      no  unknown  unknown
# 4   47       admin.  married  university.degree      no      yes       no
#
#      contact month day_of_week  ...  campaign  pdays  previous     poutcome  \
# 0   cellular   may         fri  ...         2    999         0  nonexistent
# 1  telephone   may         fri  ...         4    999         0  nonexistent
# 2  telephone   jun         wed  ...         1    999         0  nonexistent
# 3  telephone   jun         fri  ...         3    999         0  nonexistent
# 4   cellular   nov         mon  ...         1    999         0  nonexistent
#
# ...

# %%
# Create Model and training
config = {'algorithm': 'ID3'}
model = chef.fit(training_set, config)
# Out:
# ID3  tree is going to be built...
# Accuracy:  99.9 % on  1000  instances
# finished in  88.4156322479248  seconds

# %%
# Testing model
correct = 0
wrong = 0
for index, row in test_set.iterrows():
    prediction = chef.predict(model, row)
    target = row['Decision']
    if prediction == target:
        correct += 1
    else:
        wrong += 1
        
print("accuracy: %f. Correct: %d. Wrong: %d" %(float(correct/(correct+wrong)), correct, wrong))
# Out:
# accuracy: 0.834295. Correct: 2603. Wrong: 517

# %%
# print("%d,%d,%d" %(len(data), len(training_set), len(test_set)))
correct/(correct+wrong)
# Out:
# 0.8240331491712707

# %%
training_set.describe()
# Out:
#               age     duration    campaign        pdays     previous  \
# count  1000.00000  1000.000000  1000.00000  1000.000000  1000.000000
# mean     39.79200   250.074000     2.52500   958.297000     0.207000
# std      10.49814   229.871946     2.55576   196.953796     0.571382
# min      18.00000     5.000000     1.00000     1.000000     0.000000
# 25%      32.00000   102.000000     1.00000   999.000000     0.000000
# 50%      38.00000   179.000000     2.00000   999.000000     0.000000
# 75%      47.00000   314.000000     3.00000   999.000000     0.000000
# max      86.00000  1868.000000    27.00000   999.000000     6.000000
#
#        emp.var.rate  cons.price.idx  cons.conf.idx    euribor3m  nr.employed
# count   1000.000000     1000.000000    1000.000000  1000.000000  1000.000000
# mean       0.132100       93.612126     -40.710400     3.629690  5165.377300
# std        1.503076        0.565136       4.491212     1.727559    75.207707
# ...
